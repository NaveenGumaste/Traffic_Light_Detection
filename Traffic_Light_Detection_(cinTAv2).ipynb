# %%
import os

# %%
import glob

# %%
from IPython.display import Image, display

# %%
# !nvidia-smi
# Out:
# 'nvidia-smi' is not recognized as an internal or external command,
# operable program or batch file.

# %%
pip install ultralytics==8.0.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#      ---------------------------------------- 0.0/219.8 kB ? eta -:--:--
#      ----- --------------------------------- 30.7/219.8 kB 1.3 MB/s eta 0:00:01
#      ------------------------------ ------- 174.1/219.8 kB 2.6 MB/s eta 0:00:01
#      -------------------------------------- 219.8/219.8 kB 2.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/154.5 kB ? eta -:--:--
#      -------------------------------------- 154.5/154.5 kB 9.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ---------------------------------------- 61.2/61.2 kB 3.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ---------------------------------------- 60.4/60.4 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
# ...

# %%
import ultralytics

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.0  Python-3.9.18 torch-2.1.1+cpu CPU
# Setup complete  (16 CPUs, 15.6 GB RAM, 96.8/200.2 GB disk)

# %%
HOME = "E:\Traffic_Light_Detection"

# %%
print(HOME)
# Out:
# E:\Traffic_Light_Detection

# %%
# !mkdir {HOME}/datasets
# Out:
# The syntax of the command is incorrect.

# %%
# %cd {HOME}/Datasets
# Out:
# E:\Traffic_Light_Detection\Datasets

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="sRZFgPn7f9rMLPTIU8Rq")
project = rf.workspace("wawan-pradana").project("cinta_v2")
dataset = project.version(1).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.0.0, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to cinTA_v2-1 in yolov8:: 100%|██████████| 4806/4806 [00:02<00:00, 1663.96it/s]

# %%
pip install ultralytics==8.0.196
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#    ---------------------------------------- 0.0/631.1 kB ? eta -:--:--
#    ------------ --------------------------- 204.8/631.1 kB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 631.1/631.1 kB 8.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.0.0
#     Uninstalling ultralytics-8.0.0:
#       Successfully uninstalled ultralytics-8.0.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %cd {HOME}
# !yolo task=detect mode=train model=yolov8s.pt data='/content/datasets/cinTA_v2/data.yaml' epochs=75 imgsz=1000
# Out:
# /content
# New https://pypi.org/project/ultralytics/8.0.221 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls "E:\Traffic_Light_Detection\Results"
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from IPython.display import Image, display

# %%
Image(filename = r"E:\Traffic_Light_Detection\Results\train\confusion_matrix.png")

# %%
Image(filename = r"E:\Traffic_Light_Detection\Results\train\val_batch2_pred.jpg", height = 500)

# %%
# !yolo task=detect mode=val model="Results\train\weights\best.pt" data="E:\Traffic_Light_Detection\Datasets\cinTA_v2\data.yaml"
# Out:
# Ultralytics YOLOv8.0.196  Python-3.10.13 torch-2.1.1+cpu CPU (Intel Core(TM) i5-8300H 2.30GHz)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
#
# val: Scanning E:\Traffic_Light_Detection\Datasets\cinTA_v2\valid\labels...:   0%|          | 0/200 [00:00<?, ?it/s]
# val: Scanning E:\Traffic_Light_Detection\Datasets\cinTA_v2\valid\labels... 8 images, 0 backgrounds, 0 corrupt:   4%|▍         | 8/200 [00:00<00:02, 79.42it/s]
# val: Scanning E:\Traffic_Light_Detection\Datasets\cinTA_v2\valid\labels... 57 images, 0 backgrounds, 0 corrupt:  28%|██▊       | 57/200 [00:00<00:00, 309.82it/s]
# val: Scanning E:\Traffic_Light_Detection\Datasets\cinTA_v2\valid\labels... 101 images, 0 backgrounds, 0 corrupt:  50%|█████     | 101/200 [00:00<00:00, 357.30it/s]
# val: Scanning E:\Traffic_Light_Detection\Datasets\cinTA_v2\valid\labels... 150 images, 0 backgrounds, 0 corrupt:  75%|███████▌  | 150/200 [00:00<00:00, 396.42it/s]
# ...

# %%
# !yolo task=detect mode=predict model="Results\train\weights\best.pt" conf=0.25 source='bad_weather.jpg'
# Out:
# WARNING  Ultralytics settings reset to default values. This may be due to a possible problem with your settings or a recent ultralytics package update.
# View settings with 'yolo settings' or at 'C:\Users\navee\AppData\Roaming\Ultralytics\settings.yaml'
# Update settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'.
# Ultralytics YOLOv8.0.196  Python-3.9.18 torch-2.1.1+cpu CPU (12th Gen Intel Core(TM) i5-12500H)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 d:\Kle_Tech\BE\5Th-Sem\Traffic_Light_Detection\bad_weather.jpg: 608x1024 3 reds, 254.0ms
# Speed: 5.0ms preprocess, 254.0ms inference, 2.1ms postprocess per image at shape (1, 3, 608, 1024)
# Results saved to runs\detect\predict8
#  Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict model='/content/runs/detect/train2/weights/best.pt' conf=0.25 source='Traffic.mp4'
# Out:
# /content
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (1/1148) /content/Traffic.mp4: 576x1024 1 green, 115.0ms
# video 1/1 (2/1148) /content/Traffic.mp4: 576x1024 1 green, 20.2ms
# video 1/1 (3/1148) /content/Traffic.mp4: 576x1024 1 green, 20.1ms
# video 1/1 (4/1148) /content/Traffic.mp4: 576x1024 1 green, 20.1ms
# video 1/1 (5/1148) /content/Traffic.mp4: 576x1024 1 green, 20.2ms
# video 1/1 (6/1148) /content/Traffic.mp4: 576x1024 1 green, 20.1ms
# video 1/1 (7/1148) /content/Traffic.mp4: 576x1024 1 green, 20.1ms
# video 1/1 (8/1148) /content/Traffic.mp4: 576x1024 1 green, 20.1ms
# video 1/1 (9/1148) /content/Traffic.mp4: 576x1024 1 green, 20.1ms
# video 1/1 (10/1148) /content/Traffic.mp4: 576x1024 1 green, 20.1ms
# video 1/1 (11/1148) /content/Traffic.mp4: 576x1024 1 green, 20.2ms
# ...
